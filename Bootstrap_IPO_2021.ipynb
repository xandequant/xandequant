# %% [markdown]
# # Bootstrap de ações com IPO em 2021

# %% [markdown]
# # 1) Storyteling
#
# O mercado sempre teve a impressão de preço esticado no IPO de empresas.
#
# Publicado pelo estatístico Bradley Efron em 1979 no artigo "Bootstrap methods: another look at the jackknife", o Bootstrap é um método de reamostragem com reposição mais "computacional" que o seu predecessor, o jackknife.
#
# Nesse bootstrap, utilizarei o preço das 45 empresas com capital aberto em 2021. Calcularei médias, medianas e desvios para estimar e comparar a variância dos preços.
#
# Na conclusão, observamos que somente 11 empresas (com destaque aos setores de agronegócio e tecnologia) estão atualmente cotadas a preços maiores que o seu IPO.
#
# Ademais, as máximas históricas apontam para estratégia de trading short na queda dos preços pós IPO e na queda drástica dos preços pós máxima histórica.

# %% [markdown]
# Link das 45 empresas com IPO em 2021
#
# https://www.poder360.com.br/economia/75-das-empresas-que-fizeram-ipos-em-2021-tem-acoes-no-vermelho/#:~:text=Em%202021%2C%20a%20B3%20

# %% [markdown]
# # 2) Bibliotecas

# %%
# !pip install yfinance -q
import yfinance as yf
import pandas as pd
import numpy as np
from sklearn.utils import resample

# %% [markdown]
# # 3) Desenvolvendo o algoritmo

# %%
tickers = ['WEST3.SA', 'ESPA3.SA', 'DOTZ3.SA', 'MBLY3.SA', 'NINJ3.SA', 'CLSA3.SA', 'BRIT3.SA', 'LVTC3.SA', 'TRAD3.SA', 'OPCT3.SA', 'KRSA3.SA', 'HBRE3.SA',
           'CSED3.SA', 'IFCM3.SA', 'ONCO3.SA', 'MLAS3.SA', 'FIQE3.SA', 'ALLD3.SA', 'NUBR33.SA', 'DESK3.SA', 'CMIN3.SA', 'G2DI33.SA', 'MATD3.SA', 'RAIZ4.SA',
           'AGXY3.SA','ELMD3.SA', 'BMOB3.SA', 'SMFT3.SA', 'BLAU3.SA', 'VVEO3.SA', 'ARML3.SA', 'CXSE3.SA', 'JALL3.SA', 'BRBI11.SA', 'TTEN3.SA', 'IGTI3.SA',
           'CBAV3.SA', 'GGPS3.SA', 'SOJA3.SA', 'VITT3.SA', 'ORVR3.SA', 'INTB3.SA', 'RECV3.SA', 'VAMO3.SA', 'ASAI3.SA']

tickers.sort()
len(tickers)
# Out:
# 45

# %%
# Baixar cotações de empresas com IPO a partir de 2021

cotacoes_ipo_2021 = yf.download(tickers, start='2021-01-01')
# Out:
# [*********************100%***********************]  45 of 45 completed

# %%
# Dos dados OHLC, somente o adjusted close é necessário para esse estudo
cotacoes_ipo_2021_ac = round(cotacoes_ipo_2021['Adj Close'], 2)
cotacoes_ipo_2021_ac.tail()
# Out:
#             AGXY3.SA  ALLD3.SA  ARML3.SA  ASAI3.SA  BLAU3.SA  BMOB3.SA  \
# Date
# 2023-07-28      5.41      6.84     12.86     13.20     20.45     13.50
# 2023-07-31      5.45      6.85     13.12     13.47     20.78     13.50
# 2023-08-01      5.35      6.77     13.45     13.65     20.93     13.50
# 2023-08-02      5.22      6.83     13.07     13.65     21.51     13.79
# 2023-08-03      5.09      6.90     13.27     14.11     21.44     13.93
#
#             BRBI11.SA  BRIT3.SA  CBAV3.SA  CLSA3.SA  ...  RAIZ4.SA  RECV3.SA  \
# Date                                                 ...
# 2023-07-28      14.70      2.93      4.98      5.54  ...      4.12     23.16
# 2023-07-31      14.61      3.02      5.30      5.57  ...      4.16     22.99
# 2023-08-01      15.50      3.05      5.29      5.77  ...      4.16     22.92
# 2023-08-02      16.00      3.01      5.12      5.40  ...      4.19     22.60
# 2023-08-03      16.33      3.08      5.17      5.38  ...      4.13     23.08
#
#             SMFT3.SA  SOJA3.SA  TRAD3.SA  TTEN3.SA  VAMO3.SA  VITT3.SA  \
# Date
# 2023-07-28     22.75     11.38      1.50     12.28     11.71     12.30
# 2023-07-31     22.86     11.62      1.50     12.65     11.94     12.32
# 2023-08-01     23.10     11.82      1.48     12.22     12.01     12.32
# 2023-08-02     23.47     11.70      1.44     12.51     11.77     12.30
# 2023-08-03     23.29     11.69      1.47     12.50     12.08     12.10
#
#             VVEO3.SA  WEST3.SA
# Date
# 2023-07-28     21.11      1.38
# 2023-07-31     21.20      1.38
# 2023-08-01     21.67      1.26
# 2023-08-02     21.00      1.37
# 2023-08-03     20.83      1.40
#
# [5 rows x 45 columns]

# %%
# Não é necessário tratamento especial a missing values pois, simplesmente, quanto mais nan numa ação, mais recente o seu IPO.

cotacoes_ipo_2021_ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 645 entries, 2021-01-04 to 2023-08-03
# Data columns (total 45 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AGXY3.SA   506 non-null    float64
#  1   ALLD3.SA   579 non-null    float64
#  2   ARML3.SA   504 non-null    float64
#  3   ASAI3.SA   608 non-null    float64
#  4   BLAU3.SA   574 non-null    float64
#  5   BMOB3.SA   618 non-null    float64
#  6   BRBI11.SA  514 non-null    float64
#  7   BRIT3.SA   502 non-null    float64
#  8   CBAV3.SA   513 non-null    float64
#  9   CLSA3.SA   502 non-null    float64
#  10  CMIN3.SA   613 non-null    float64
#  11  CSED3.SA   618 non-null    float64
#  12  CXSE3.SA   566 non-null    float64
#  13  DESK3.SA   509 non-null    float64
#  14  DOTZ3.SA   545 non-null    float64
#  15  ELMD3.SA   616 non-null    float64
#  16  ESPA3.SA   623 non-null    float64
#  17  FIQE3.SA   504 non-null    float64
#  18  G2DI33.SA  554 non-null    float64
#  19  GGPS3.SA   568 non-null    float64
#  20  HBRE3.SA   630 non-null    float64
#  21  IFCM3.SA   561 non-null    float64
#  22  IGTI3.SA   645 non-null    float64
#  23  INTB3.SA   621 non-null    float64
#  24  JALL3.SA   621 non-null    float64
#  25  KRSA3.SA   492 non-null    float64
#  26  LVTC3.SA   504 non-null    float64
#  27  MATD3.SA   557 non-null    float64
#  28  MBLY3.SA   620 non-null    float64
#  29  MLAS3.SA   509 non-null    float64
#  30  NINJ3.SA   554 non-null    float64
#  31  NUBR33.SA  248 non-null    float64
#  32  ONCO3.SA   467 non-null    float64
#  33  OPCT3.SA   617 non-null    float64
#  34  ORVR3.SA   616 non-null    float64
#  35  RAIZ4.SA   499 non-null    float64
#  36  RECV3.SA   563 non-null    float64
#  37  SMFT3.SA   515 non-null    float64
#  38  SOJA3.SA   566 non-null    float64
#  39  TRAD3.SA   505 non-null    float64
#  40  TTEN3.SA   511 non-null    float64
#  41  VAMO3.SA   625 non-null    float64
#  42  VITT3.SA   479 non-null    float64
#  43  VVEO3.SA   497 non-null    float64
#  44  WEST3.SA   617 non-null    float64
# dtypes: float64(45)
# memory usage: 231.8 KB

# %%
# Criar o bootstrap

for coluna_ticker, cotac_hist in cotacoes_ipo_2021_ac.items():                                                # Iterar sobre a coluna ticker de cada empresa, em suas cotações históricas
  results = []

  for nrepeat in range(1000):                                                                                 # Iterar mil repetições com reposição pelo método resample do sklearn
    amostra = resample(cotac_hist)
    results.append(amostra.median())
  results = pd.Series(results)
  print(coluna_ticker,':', round(cotac_hist[-1],2))                                                           # Ticker: cotação atual
  print('Cotação 1º dia de IPO: ', round(cotac_hist.loc[~cotac_hist.isnull()][0],2))
  print('Mínima histórica: ', round(cotac_hist.min(),2),'. Máxima histórica:', round(cotac_hist.max(),2))     # Cotações mínima e máxima
  print('Variação Máxima % desde o IPO: ', round((cotac_hist.max() - cotac_hist[-1]) / cotac_hist[-1]*100,2))
  print('Média da cotação histórica indica o seguinte preço: ', round(cotac_hist.mean(),2))                   # Média da cotação histórica
  print('Mediana da cotação histórica indica o seguinte preço: ', round(cotac_hist.median(),2))               # Mediana da cotação histórica
  print('Mediana do Bootstrap indica o seguinte preço: ', round(results.median(),2))
  print('Distribuição do Bootstrap comparado à cotação histórica estima um viés de: ', round(results.mean() - cotac_hist.median(),2), 'no preço atual')
  print('Desvio Padrão do Bootstrap: ', round(results.std(),2), '. Isso indica um preço histórico entre:', round(results.mean() - results.std(),2), ' e:', round(results.mean() + results.std(),2))
  print('Isso indica uma variação percentual média, desde o IPO', 'de: ', (results.mean() + results.std() - (results.mean() - results.std())) / (results.mean() - results.std())*100)
  print('________________')
# Out:
# AGXY3.SA : 5.09
# Cotação 1º dia de IPO:  10.11
# Mínima histórica:  5.09 . Máxima histórica: 11.73
# Variação Máxima % desde o IPO:  130.45
# Média da cotação histórica indica o seguinte preço:  8.36
# Mediana da cotação histórica indica o seguinte preço:  8.35
# Mediana do Bootstrap indica o seguinte preço:  8.35
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.12 . Isso indica um preço histórico entre: 8.21  e: 8.46
# Isso indica uma variação percentual média, desde o IPO de:  2.973641675234857
# ________________
# ALLD3.SA : 6.9
# Cotação 1º dia de IPO:  15.03
# Mínima histórica:  4.5 . Máxima histórica: 33.47
# Variação Máxima % desde o IPO:  385.07
# Média da cotação histórica indica o seguinte preço:  12.05
# Mediana da cotação histórica indica o seguinte preço:  11.14
# Mediana do Bootstrap indica o seguinte preço:  11.14
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.1 no preço atual
# Desvio Padrão do Bootstrap:  0.56 . Isso indica um preço histórico entre: 10.48  e: 11.61
# Isso indica uma variação percentual média, desde o IPO de:  10.724511245030428
# ________________
# ARML3.SA : 13.27
# Cotação 1º dia de IPO:  21.11
# Mínima histórica:  9.34 . Máxima histórica: 25.73
# Variação Máxima % desde o IPO:  93.9
# Média da cotação histórica indica o seguinte preço:  15.63
# Mediana da cotação histórica indica o seguinte preço:  14.65
# Mediana do Bootstrap indica o seguinte preço:  14.64
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.18 . Isso indica um preço histórico entre: 14.46  e: 14.82
# Isso indica uma variação percentual média, desde o IPO de:  2.5118876213166734
# ________________
# ASAI3.SA : 14.11
# Cotação 1º dia de IPO:  13.99
# Mínima histórica:  10.5 . Máxima histórica: 21.02
# Variação Máxima % desde o IPO:  48.97
# Média da cotação histórica indica o seguinte preço:  15.87
# Mediana da cotação histórica indica o seguinte preço:  15.82
# Mediana do Bootstrap indica o seguinte preço:  15.86
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.03 no preço atual
# Desvio Padrão do Bootstrap:  0.12 . Isso indica um preço histórico entre: 15.74  e: 15.97
# Isso indica uma variação percentual média, desde o IPO de:  1.4760546858885109
# ________________
# BLAU3.SA : 21.44
# Cotação 1º dia de IPO:  38.58
# Mínima histórica:  17.95 . Máxima histórica: 50.66
# Variação Máxima % desde o IPO:  136.29
# Média da cotação histórica indica o seguinte preço:  30.6
# Mediana da cotação histórica indica o seguinte preço:  28.78
# Mediana do Bootstrap indica o seguinte preço:  28.71
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.03 no preço atual
# Desvio Padrão do Bootstrap:  0.46 . Isso indica um preço histórico entre: 28.29  e: 29.21
# Isso indica uma variação percentual média, desde o IPO de:  3.2582214078198413
# ________________
# BMOB3.SA : 13.93
# Cotação 1º dia de IPO:  21.48
# Mínima histórica:  10.63 . Máxima histórica: 25.79
# Variação Máxima % desde o IPO:  85.14
# Média da cotação histórica indica o seguinte preço:  15.64
# Mediana da cotação histórica indica o seguinte preço:  14.36
# Mediana do Bootstrap indica o seguinte preço:  14.36
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.08 . Isso indica um preço histórico entre: 14.3  e: 14.46
# Isso indica uma variação percentual média, desde o IPO de:  1.0984223739238896
# ________________
# BRBI11.SA : 16.33
# Cotação 1º dia de IPO:  17.86
# Mínima histórica:  9.44 . Máxima histórica: 24.69
# Variação Máxima % desde o IPO:  51.19
# Média da cotação histórica indica o seguinte preço:  13.96
# Mediana da cotação histórica indica o seguinte preço:  13.73
# Mediana do Bootstrap indica o seguinte preço:  13.73
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.09 . Isso indica um preço histórico entre: 13.64  e: 13.82
# Isso indica uma variação percentual média, desde o IPO de:  1.323434971989871
# ________________
# BRIT3.SA : 3.08
# Cotação 1º dia de IPO:  13.4
# Mínima histórica:  1.73 . Máxima histórica: 13.4
# Variação Máxima % desde o IPO:  335.06
# Média da cotação histórica indica o seguinte preço:  4.13
# Mediana da cotação histórica indica o seguinte preço:  3.05
# Mediana do Bootstrap indica o seguinte preço:  3.05
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.05 . Isso indica um preço histórico entre: 3.01  e: 3.11
# Isso indica uma variação percentual média, desde o IPO de:  3.272816008748298
# ________________
# CBAV3.SA : 5.17
# Cotação 1º dia de IPO:  10.91
# Mínima histórica:  4.53 . Máxima histórica: 21.52
# Variação Máxima % desde o IPO:  316.25
# Média da cotação histórica indica o seguinte preço:  11.08
# Mediana da cotação histórica indica o seguinte preço:  10.99
# Mediana do Bootstrap indica o seguinte preço:  10.99
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.04 no preço atual
# Desvio Padrão do Bootstrap:  0.12 . Isso indica um preço histórico entre: 10.9  e: 11.15
# Isso indica uma variação percentual média, desde o IPO de:  2.2348555058242554
# ________________
# CLSA3.SA : 5.38
# Cotação 1º dia de IPO:  29.69
# Mínima histórica:  3.55 . Máxima histórica: 29.69
# Variação Máxima % desde o IPO:  451.86
# Média da cotação histórica indica o seguinte preço:  8.91
# Mediana da cotação histórica indica o seguinte preço:  5.94
# Mediana do Bootstrap indica o seguinte preço:  5.94
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.08 . Isso indica um preço histórico entre: 5.86  e: 6.01
# Isso indica uma variação percentual média, desde o IPO de:  2.5886257987114165
# ________________
# CMIN3.SA : 4.28
# Cotação 1º dia de IPO:  6.45
# Mínima histórica:  2.6 . Máxima histórica: 7.61
# Variação Máxima % desde o IPO:  77.8
# Média da cotação histórica indica o seguinte preço:  4.53
# Mediana da cotação histórica indica o seguinte preço:  4.4
# Mediana do Bootstrap indica o seguinte preço:  4.4
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.03 . Isso indica um preço histórico entre: 4.36  e: 4.43
# Isso indica uma variação percentual média, desde o IPO de:  1.548922296674665
# ________________
# CSED3.SA : 4.59
# Cotação 1º dia de IPO:  12.15
# Mínima histórica:  1.95 . Máxima histórica: 15.27
# Variação Máxima % desde o IPO:  232.68
# Média da cotação histórica indica o seguinte preço:  6.09
# Mediana da cotação histórica indica o seguinte preço:  4.54
# Mediana do Bootstrap indica o seguinte preço:  4.54
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.09 . Isso indica um preço histórico entre: 4.47  e: 4.64
# Isso indica uma variação percentual média, desde o IPO de:  3.9172193728364424
# ________________
# CXSE3.SA : 10.94
# Cotação 1º dia de IPO:  8.56
# Mínima histórica:  6.05 . Máxima histórica: 11.47
# Variação Máxima % desde o IPO:  4.84
# Média da cotação histórica indica o seguinte preço:  8.23
# Mediana da cotação histórica indica o seguinte preço:  7.97
# Mediana do Bootstrap indica o seguinte preço:  7.97
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.03 . Isso indica um preço histórico entre: 7.94  e: 8.01
# Isso indica uma variação percentual média, desde o IPO de:  0.8559238289900708
# ________________
# DESK3.SA : 14.21
# Cotação 1º dia de IPO:  24.67
# Mínima histórica:  6.27 . Máxima histórica: 26.37
# Variação Máxima % desde o IPO:  85.57
# Média da cotação histórica indica o seguinte preço:  13.08
# Mediana da cotação histórica indica o seguinte preço:  11.22
# Mediana do Bootstrap indica o seguinte preço:  11.22
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.2 . Isso indica um preço histórico entre: 11.03  e: 11.43
# Isso indica uma variação percentual média, desde o IPO de:  3.650727576115581
# ________________
# DOTZ3.SA : 1.35
# Cotação 1º dia de IPO:  13.2
# Mínima histórica:  0.76 . Máxima histórica: 17.15
# Variação Máxima % desde o IPO:  1170.37
# Média da cotação histórica indica o seguinte preço:  3.87
# Mediana da cotação histórica indica o seguinte preço:  2.69
# Mediana do Bootstrap indica o seguinte preço:  2.69
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.09 . Isso indica um preço histórico entre: 2.62  e: 2.8
# Isso indica uma variação percentual média, desde o IPO de:  6.7813353297662635
# ________________
# ELMD3.SA : 14.95
# Cotação 1º dia de IPO:  17.5
# Mínima histórica:  9.4 . Máxima histórica: 22.79
# Variação Máxima % desde o IPO:  52.44
# Média da cotação histórica indica o seguinte preço:  14.58
# Mediana da cotação histórica indica o seguinte preço:  14.84
# Mediana do Bootstrap indica o seguinte preço:  14.85
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.17 . Isso indica um preço histórico entre: 14.65  e: 14.99
# Isso indica uma variação percentual média, desde o IPO de:  2.2702351170035073
# ________________
# ESPA3.SA : 1.58
# Cotação 1º dia de IPO:  21.5
# Mínima histórica:  0.95 . Máxima histórica: 21.5
# Variação Máxima % desde o IPO:  1260.76
# Média da cotação histórica indica o seguinte preço:  7.27
# Mediana da cotação histórica indica o seguinte preço:  3.68
# Mediana do Bootstrap indica o seguinte preço:  3.7
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.44 . Isso indica um preço histórico entre: 3.23  e: 4.12
# Isso indica uma variação percentual média, desde o IPO de:  27.260287815898998
# ________________
# FIQE3.SA : 4.19
# Cotação 1º dia de IPO:  8.29
# Mínima histórica:  2.87 . Máxima histórica: 8.29
# Variação Máxima % desde o IPO:  97.85
# Média da cotação histórica indica o seguinte preço:  4.57
# Mediana da cotação histórica indica o seguinte preço:  4.19
# Mediana do Bootstrap indica o seguinte preço:  4.18
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.06 . Isso indica um preço histórico entre: 4.13  e: 4.24
# Isso indica uma variação percentual média, desde o IPO de:  2.6801784592403095
# ________________
# G2DI33.SA : 2.23
# Cotação 1º dia de IPO:  6.55
# Mínima histórica:  1.82 . Máxima histórica: 7.5
# Variação Máxima % desde o IPO:  236.32
# Média da cotação histórica indica o seguinte preço:  4.16
# Mediana da cotação histórica indica o seguinte preço:  3.68
# Mediana do Bootstrap indica o seguinte preço:  3.68
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.22 . Isso indica um preço histórico entre: 3.47  e: 3.92
# Isso indica uma variação percentual média, desde o IPO de:  12.928241434385724
# ________________
# GGPS3.SA : 17.72
# Cotação 1º dia de IPO:  12.67
# Mínima histórica:  10.13 . Máxima histórica: 19.35
# Variação Máxima % desde o IPO:  9.2
# Média da cotação histórica indica o seguinte preço:  14.29
# Mediana da cotação histórica indica o seguinte preço:  14.14
# Mediana do Bootstrap indica o seguinte preço:  14.14
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.19 . Isso indica um preço histórico entre: 13.94  e: 14.32
# Isso indica uma variação percentual média, desde o IPO de:  2.7040050409200838
# ________________
# HBRE3.SA : 5.76
# Cotação 1º dia de IPO:  18.9
# Mínima histórica:  3.65 . Máxima histórica: 18.9
# Variação Máxima % desde o IPO:  228.12
# Média da cotação histórica indica o seguinte preço:  8.78
# Mediana da cotação histórica indica o seguinte preço:  6.38
# Mediana do Bootstrap indica o seguinte preço:  6.38
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.08 no preço atual
# Desvio Padrão do Bootstrap:  0.23 . Isso indica um preço histórico entre: 6.07  e: 6.54
# Isso indica uma variação percentual média, desde o IPO de:  7.717628416937466
# ________________
# IFCM3.SA : 1.76
# Cotação 1º dia de IPO:  15.2
# Mínima histórica:  0.96 . Máxima histórica: 23.78
# Variação Máxima % desde o IPO:  1251.14
# Média da cotação histórica indica o seguinte preço:  9.09
# Mediana da cotação histórica indica o seguinte preço:  5.94
# Mediana do Bootstrap indica o seguinte preço:  5.94
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.04 no preço atual
# Desvio Padrão do Bootstrap:  0.19 . Isso indica um preço histórico entre: 5.79  e: 6.18
# Isso indica uma variação percentual média, desde o IPO de:  6.687083957081065
# ________________
# IGTI3.SA : 2.86
# Cotação 1º dia de IPO:  2.39
# Mínima histórica:  2.06 . Máxima histórica: 3.52
# Variação Máxima % desde o IPO:  23.08
# Média da cotação histórica indica o seguinte preço:  2.62
# Mediana da cotação histórica indica o seguinte preço:  2.57
# Mediana do Bootstrap indica o seguinte preço:  2.57
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.01 . Isso indica um preço histórico entre: 2.56  e: 2.59
# Isso indica uma variação percentual média, desde o IPO de:  1.0212331249139848
# ________________
# INTB3.SA : 23.45
# Cotação 1º dia de IPO:  18.54
# Mínima histórica:  16.34 . Máxima histórica: 35.74
# Variação Máxima % desde o IPO:  52.41
# Média da cotação histórica indica o seguinte preço:  26.75
# Mediana da cotação histórica indica o seguinte preço:  26.91
# Mediana do Bootstrap indica o seguinte preço:  26.9
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.11 . Isso indica um preço histórico entre: 26.78  e: 27.0
# Isso indica uma variação percentual média, desde o IPO de:  0.819551425696563
# ________________
# JALL3.SA : 8.24
# Cotação 1º dia de IPO:  8.13
# Mínima histórica:  6.22 . Máxima histórica: 10.51
# Variação Máxima % desde o IPO:  27.55
# Média da cotação histórica indica o seguinte preço:  7.96
# Mediana da cotação histórica indica o seguinte preço:  7.86
# Mediana do Bootstrap indica o seguinte preço:  7.86
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.07 . Isso indica um preço histórico entre: 7.77  e: 7.91
# Isso indica uma variação percentual média, desde o IPO de:  1.8834602598731522
# ________________
# KRSA3.SA : 1.45
# Cotação 1º dia de IPO:  8.0
# Mínima histórica:  0.78 . Máxima histórica: 8.15
# Variação Máxima % desde o IPO:  462.07
# Média da cotação histórica indica o seguinte preço:  3.02
# Mediana da cotação histórica indica o seguinte preço:  2.83
# Mediana do Bootstrap indica o seguinte preço:  2.83
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.08 . Isso indica um preço histórico entre: 2.73  e: 2.89
# Isso indica uma variação percentual média, desde o IPO de:  5.857219868117519
# ________________
# LVTC3.SA : 5.93
# Cotação 1º dia de IPO:  23.5
# Mínima histórica:  4.9 . Máxima histórica: 26.19
# Variação Máxima % desde o IPO:  341.65
# Média da cotação histórica indica o seguinte preço:  10.48
# Mediana da cotação histórica indica o seguinte preço:  7.78
# Mediana do Bootstrap indica o seguinte preço:  7.78
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.04 no preço atual
# Desvio Padrão do Bootstrap:  0.17 . Isso indica um preço histórico entre: 7.57  e: 7.91
# Isso indica uma variação percentual média, desde o IPO de:  4.5167001141062775
# ________________
# MATD3.SA : 10.53
# Cotação 1º dia de IPO:  15.51
# Mínima histórica:  6.11 . Máxima histórica: 21.22
# Variação Máxima % desde o IPO:  101.52
# Média da cotação histórica indica o seguinte preço:  11.83
# Mediana da cotação histórica indica o seguinte preço:  10.26
# Mediana do Bootstrap indica o seguinte preço:  10.26
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.08 no preço atual
# Desvio Padrão do Bootstrap:  0.26 . Isso indica um preço histórico entre: 9.92  e: 10.44
# Isso indica uma variação percentual média, desde o IPO de:  5.19778838807915
# ________________
# MBLY3.SA : 3.94
# Cotação 1º dia de IPO:  26.4
# Mínima histórica:  1.73 . Máxima histórica: 26.4
# Variação Máxima % desde o IPO:  570.05
# Média da cotação histórica indica o seguinte preço:  7.25
# Mediana da cotação histórica indica o seguinte preço:  4.42
# Mediana do Bootstrap indica o seguinte preço:  4.41
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.21 . Isso indica um preço histórico entre: 4.22  e: 4.64
# Isso indica uma variação percentual média, desde o IPO de:  9.97107852720265
# ________________
# MLAS3.SA : 3.43
# Cotação 1º dia de IPO:  12.64
# Mínima histórica:  1.26 . Máxima histórica: 12.67
# Variação Máxima % desde o IPO:  269.39
# Média da cotação histórica indica o seguinte preço:  5.0
# Mediana da cotação histórica indica o seguinte preço:  4.86
# Mediana do Bootstrap indica o seguinte preço:  4.86
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.08 . Isso indica um preço histórico entre: 4.78  e: 4.95
# Isso indica uma variação percentual média, desde o IPO de:  3.490672546388851
# ________________
# NINJ3.SA : 3.76
# Cotação 1º dia de IPO:  18.35
# Mínima histórica:  2.16 . Máxima histórica: 27.05
# Variação Máxima % desde o IPO:  619.41
# Média da cotação histórica indica o seguinte preço:  6.21
# Mediana da cotação histórica indica o seguinte preço:  3.59
# Mediana do Bootstrap indica o seguinte preço:  3.59
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.07 . Isso indica um preço histórico entre: 3.52  e: 3.65
# Isso indica uma variação percentual média, desde o IPO de:  3.861825465703191
# ________________
# NUBR33.SA : 6.3
# Cotação 1º dia de IPO:  3.98
# Mínima histórica:  3.04 . Máxima histórica: 6.53
# Variação Máxima % desde o IPO:  3.65
# Média da cotação histórica indica o seguinte preço:  4.39
# Mediana da cotação histórica indica o seguinte preço:  4.1
# Mediana do Bootstrap indica o seguinte preço:  4.09
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.04 . Isso indica um preço histórico entre: 4.06  e: 4.14
# Isso indica uma variação percentual média, desde o IPO de:  1.9749686295934896
# ________________
# ONCO3.SA : 11.83
# Cotação 1º dia de IPO:  14.77
# Mínima histórica:  4.21 . Máxima histórica: 15.41
# Variação Máxima % desde o IPO:  30.26
# Média da cotação histórica indica o seguinte preço:  8.45
# Mediana da cotação histórica indica o seguinte preço:  8.0
# Mediana do Bootstrap indica o seguinte preço:  8.0
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.08 no preço atual
# Desvio Padrão do Bootstrap:  0.25 . Isso indica um preço histórico entre: 7.83  e: 8.34
# Isso indica uma variação percentual média, desde o IPO de:  6.5111785244650235
# ________________
# OPCT3.SA : 5.41
# Cotação 1º dia de IPO:  11.15
# Mínima histórica:  1.62 . Máxima histórica: 11.15
# Variação Máxima % desde o IPO:  106.1
# Média da cotação histórica indica o seguinte preço:  4.15
# Mediana da cotação histórica indica o seguinte preço:  3.05
# Mediana do Bootstrap indica o seguinte preço:  3.05
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.05 . Isso indica um preço histórico entre: 3.0  e: 3.1
# Isso indica uma variação percentual média, desde o IPO de:  3.4089145745428513
# ________________
# ORVR3.SA : 38.63
# Cotação 1º dia de IPO:  22.0
# Mínima histórica:  19.7 . Máxima histórica: 46.68
# Variação Máxima % desde o IPO:  20.84
# Média da cotação histórica indica o seguinte preço:  31.07
# Mediana da cotação histórica indica o seguinte preço:  29.73
# Mediana do Bootstrap indica o seguinte preço:  29.73
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.11 no preço atual
# Desvio Padrão do Bootstrap:  0.42 . Isso indica um preço histórico entre: 29.42  e: 30.26
# Isso indica uma variação percentual média, desde o IPO de:  2.8618786656169326
# ________________
# RAIZ4.SA : 4.13
# Cotação 1º dia de IPO:  6.67
# Mínima histórica:  2.25 . Máxima histórica: 6.83
# Variação Máxima % desde o IPO:  65.38
# Média da cotação histórica indica o seguinte preço:  4.67
# Mediana da cotação histórica indica o seguinte preço:  4.41
# Mediana do Bootstrap indica o seguinte preço:  4.41
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.12 . Isso indica um preço histórico entre: 4.29  e: 4.52
# Isso indica uma variação percentual média, desde o IPO de:  5.4323371569602825
# ________________
# RECV3.SA : 23.08
# Cotação 1º dia de IPO:  14.85
# Mínima histórica:  12.9 . Máxima histórica: 34.58
# Variação Máxima % desde o IPO:  49.83
# Média da cotação histórica indica o seguinte preço:  21.68
# Mediana da cotação histórica indica o seguinte preço:  20.55
# Mediana do Bootstrap indica o seguinte preço:  20.55
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.35 . Isso indica um preço histórico entre: 20.22  e: 20.91
# Isso indica uma variação percentual média, desde o IPO de:  3.442263244357485
# ________________
# SMFT3.SA : 23.29
# Cotação 1º dia de IPO:  31.0
# Mínima histórica:  9.97 . Máxima histórica: 32.2
# Variação Máxima % desde o IPO:  38.26
# Média da cotação histórica indica o seguinte preço:  17.94
# Mediana da cotação histórica indica o seguinte preço:  16.58
# Mediana do Bootstrap indica o seguinte preço:  16.58
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.03 no preço atual
# Desvio Padrão do Bootstrap:  0.17 . Isso indica um preço histórico entre: 16.38  e: 16.72
# Isso indica uma variação percentual média, desde o IPO de:  2.097407061429453
# ________________
# SOJA3.SA : 11.69
# Cotação 1º dia de IPO:  16.03
# Mínima histórica:  9.48 . Máxima histórica: 16.7
# Variação Máxima % desde o IPO:  42.86
# Média da cotação histórica indica o seguinte preço:  12.84
# Mediana da cotação histórica indica o seguinte preço:  12.88
# Mediana do Bootstrap indica o seguinte preço:  12.89
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.02 no preço atual
# Desvio Padrão do Bootstrap:  0.08 . Isso indica um preço histórico entre: 12.82  e: 12.98
# Isso indica uma variação percentual média, desde o IPO de:  1.2451340317232633
# ________________
# TRAD3.SA : 1.47
# Cotação 1º dia de IPO:  12.6
# Mínima histórica:  0.82 . Máxima histórica: 13.21
# Variação Máxima % desde o IPO:  798.64
# Média da cotação histórica indica o seguinte preço:  4.07
# Mediana da cotação histórica indica o seguinte preço:  4.18
# Mediana do Bootstrap indica o seguinte preço:  4.18
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.09 . Isso indica um preço histórico entre: 4.08  e: 4.26
# Isso indica uma variação percentual média, desde o IPO de:  4.522627971344061
# ________________
# TTEN3.SA : 12.5
# Cotação 1º dia de IPO:  11.37
# Mínima histórica:  6.82 . Máxima histórica: 13.54
# Variação Máxima % desde o IPO:  8.32
# Média da cotação histórica indica o seguinte preço:  10.28
# Mediana da cotação histórica indica o seguinte preço:  9.88
# Mediana do Bootstrap indica o seguinte preço:  9.88
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.1 . Isso indica um preço histórico entre: 9.79  e: 9.98
# Isso indica uma variação percentual média, desde o IPO de:  1.9913943065467614
# ________________
# VAMO3.SA : 12.08
# Cotação 1º dia de IPO:  7.7
# Mínima histórica:  7.04 . Máxima histórica: 17.39
# Variação Máxima % desde o IPO:  43.96
# Média da cotação histórica indica o seguinte preço:  12.5
# Mediana da cotação histórica indica o seguinte preço:  12.49
# Mediana do Bootstrap indica o seguinte preço:  12.49
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.12 . Isso indica um preço histórico entre: 12.37  e: 12.61
# Isso indica uma variação percentual média, desde o IPO de:  1.966901823716674
# ________________
# VITT3.SA : 12.1
# Cotação 1º dia de IPO:  9.22
# Mínima histórica:  8.25 . Máxima histórica: 14.61
# Variação Máxima % desde o IPO:  20.74
# Média da cotação histórica indica o seguinte preço:  11.09
# Mediana da cotação histórica indica o seguinte preço:  11.17
# Mediana do Bootstrap indica o seguinte preço:  11.17
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.0 no preço atual
# Desvio Padrão do Bootstrap:  0.06 . Isso indica um preço histórico entre: 11.11  e: 11.23
# Isso indica uma variação percentual média, desde o IPO de:  1.0825790498620913
# ________________
# VVEO3.SA : 20.83
# Cotação 1º dia de IPO:  20.92
# Mínima histórica:  12.8 . Máxima histórica: 26.04
# Variação Máxima % desde o IPO:  25.01
# Média da cotação histórica indica o seguinte preço:  17.49
# Mediana da cotação histórica indica o seguinte preço:  17.0
# Mediana do Bootstrap indica o seguinte preço:  16.99
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.01 no preço atual
# Desvio Padrão do Bootstrap:  0.12 . Isso indica um preço histórico entre: 16.87  e: 17.11
# Isso indica uma variação percentual média, desde o IPO de:  1.3825356266288034
# ________________
# WEST3.SA : 1.4
# Cotação 1º dia de IPO:  11.59
# Mínima histórica:  0.86 . Máxima histórica: 12.18
# Variação Máxima % desde o IPO:  770.0
# Média da cotação histórica indica o seguinte preço:  3.73
# Mediana da cotação histórica indica o seguinte preço:  2.53
# Mediana do Bootstrap indica o seguinte preço:  2.53
# Distribuição do Bootstrap comparado à cotação histórica estima um viés de:  -0.03 no preço atual
# Desvio Padrão do Bootstrap:  0.11 . Isso indica um preço histórico entre: 2.38  e: 2.61
# Isso indica uma variação percentual média, desde o IPO de:  9.641153179028555
# ________________

# %% [markdown]
# #

# %%
# Das 45 empresas, somente as 11 abaixo possuem cotação atual maior que a cotação no dia do IPO.

cotatual_maior_ipo = {'Ticker':  ['CXSE3', 'GGPS3', 'INTB3', 'JALL3', 'NUBR33', 'ORVR3', 'RECV3', 'TTEN3', 'VAMO3', 'VITT3', 'VVEO3'],
      'Atividade' : ['Seguros', 'Administração Patrimonial', 'Segurança da informação e Energia', 'Tecnologia Sucroenergética', 'Banco (fintech)', 'Bioenergia, Energia Renovável e Materiais Recicláveis', 'Petróleo em terra e Gás natural', 'Agronegócio', 'Locação/Venda de caminhões, máquinas e equipamentos', 'Agronegócio', 'Holding (Grupo Mafra), Distribuidora de laboratórios e Logística hospitalar'],}

len(cotatual_maior_ipo)
# Out:
# 2

# %%
pd.DataFrame(cotatual_maior_ipo)
# Out:
#     Ticker                                          Atividade
# 0    CXSE3                                            Seguros
# 1    GGPS3                          Administração Patrimonial
# 2    INTB3                  Segurança da informação e Energia
# 3    JALL3                         Tecnologia Sucroenergética
# 4   NUBR33                                    Banco (fintech)
# 5    ORVR3  Bioenergia, Energia Renovável e Materiais Reci...
# 6    RECV3                    Petróleo em terra e Gás natural
# 7    TTEN3                                        Agronegócio
# 8    VAMO3  Locação/Venda de caminhões, máquinas e equipam...
# 9    VITT3                                        Agronegócio
# 10   VVEO3  Holding (Grupo Mafra), Distribuidora de labora...

# %% [markdown]
# # 4) Conclusão
#
# 1) Todas as 45 empresas apresentaram alta variação percentual entre a máxima histórica e o preço atual. Tal fato é corroborado por um preço de IPO esticado e a necessidade do desenvolvimento de uma estratégia de algo trading operando short ( ou seja, "apostando" na queda do preço pós IPO e principalmente na queda drástica do preço pós máxima. Ok, sabemos que não é fácil.).
#
#
# 2) Somente 11 empresas apresentaram cotação atual maior que a cotação no 1º dia do IPO.
#
# Tal fato indica, em princípio, percepção de valor por parte do investidor.
# Isso se reflete no preço atual das empresas conforme o dataframe 'cotatual_maior_ipo'. Tais atividades são o agronegócio e suas tecnologias.
